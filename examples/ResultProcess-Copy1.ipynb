# %%
import sys
import logging, os
import numpy as np
# To import pyface.py is just for setting "Qt" sip API version to 2 before matplotlib sets it to default v1 
# that is incompatible with "pyside" in package "mayavi". wwc
import pyface.qt    
import matplotlib.pyplot as plt
from multiprocessing import Pool    # parallel computation.
import mayavi

sys.path.append('../')   # add path of package "bem" to search list. wwc
sys.path.append('../../bem/')   # add path of package "electrode" to search list. wwc

# !pwd
# Out:
# /home/wwc/bem_git/electrode/examples

# %%
# electrode is an another package in nist-ionstorage github. wwc
from electrode import System, GridElectrode

# load the electrostatics results into a electrode.System()
s = System()
#for name in "DC1 DC2 DC3 DC4 DC5 RF".split():
for name in "DC1 DC2 DC3 DC4 DC5 RF".split():
    # r = Result.from_vtk(prefix, name)
    # r after from_result(): e ~ obj = cls(origin=origin, spacing=spacing, data=pot). 
    # A vtk file after from_vtk(): obj = cls(origin=origin, spacing=spacing, data=pot). 
    # So after using from_vtk() we jump over r and get to e.
    e = GridElectrode.from_vtk("../../bem/examples/SimpleTrap/SimpleTrap_"+name+".vtk",maxderiv=0)    
    e.name = name
    s.append(e)
s["RF"].rf = 1.

# %%
e = GridElectrode.from_vtk("../../bem/examples/SimpleTrap/SimpleTrap_DC1.vtk",maxderiv=2)
print(e.name, e.origin, e.spacing)
print(len(e.data),type(e.data))
print(e.data[0].shape)
print(len(e.data),e.data[0].shape)
e.data
# Out:
#  [-1.55 -1.55 -1.55] [0.1 0.1 0.1]
# 2 <class 'list'>
# (32, 32, 32, 1)
# 2 (32, 32, 32, 1)
# [array([[[[0.0534359],
#           [0.0509338],
#           [0.0482924],
#           ...,
#           [0.0482924],
#           [0.0509338],
#           [0.0534359]],
#
#          [[0.0529044],
#           [0.0504267],
#           [0.0478116],
#           ...,
#           [0.0478116],
#           [0.0504267],
#           [0.0529044]],
#
#          [[0.0523374],
#           [0.0498844],
#           [0.047296 ],
#           ...,
#           [0.047296 ],
#           [0.0498844],
#           [0.0523374]],
#
#          ...,
#
#          [[0.0317554],
#           [0.0300128],
#           [0.0282197],
#           ...,
#           [0.0282197],
#           [0.0300128],
#           [0.0317554]],
#
#          [[0.0311033],
#           [0.0293868],
#           [0.0276218],
#           ...,
#           [0.0276218],
#           [0.0293868],
#           [0.0311033]],
#
#          [[0.0304711],
#           [0.0287803],
#           [0.0270431],
#           ...,
#           [0.0270431],
#           [0.0287803],
#           [0.0304711]]],
#
#
#         [[[0.0558952],
#           [0.0533413],
#           [0.0506357],
#           ...,
#           [0.0506357],
#           [0.0533413],
#           [0.0558952]],
#
#          [[0.0553339],
#           [0.0528054],
#           [0.0501272],
#           ...,
#           [0.0501272],
#           [0.0528054],
#           [0.0553339]],
#
#          [[0.0547321],
#           [0.0522291],
#           [0.0495787],
#           ...,
#           [0.0495787],
#           [0.0522291],
#           [0.0547321]],
#
#          ...,
#
#          [[0.0326095],
#           [0.0308311],
#           [0.0289991],
#           ...,
#           [0.0289991],
#           [0.0308311],
#           [0.0326095]],
#
#          [[0.0319172],
#           [0.0301659],
#           [0.0283633],
#           ...,
#           [0.0283633],
#           [0.0301659],
#           [0.0319172]],
#
#          [[0.0312469],
#           [0.0295223],
#           [0.0277487],
#           ...,
#           [0.0277487],
#           [0.0295223],
#           [0.0312469]]],
#
#
#         [[[0.0585444],
#           [0.0559417],
#           [0.0531737],
#           ...,
#           [0.0531737],
#           [0.0559417],
#           [0.0585444]],
#
#          [[0.0579506],
#           [0.0553745],
#           [0.0526353],
#           ...,
#           [0.0526353],
#           [0.0553745],
#           [0.0579506]],
#
#          [[0.0573106],
#           [0.0547611],
#           [0.0520509],
#           ...,
#           [0.0520509],
#           [0.0547611],
#           [0.0573106]],
#
#          ...,
#
#          [[0.0334965],
#           [0.0316815],
#           [0.0298098],
#           ...,
#           [0.0298098],
#           [0.0316815],
#           [0.0334965]],
#
#          [[0.0327615],
#           [0.0309745],
#           [0.0291335],
#           ...,
#           [0.0291335],
#           [0.0309745],
#           [0.0327615]],
#
#          [[0.0320506],
#           [0.0302914],
#           [0.0284805],
#           ...,
#           [0.0284805],
#           [0.0302914],
#           [0.0320506]]],
#
#
#         ...,
#
#
#         [[[0.27552  ],
#           [0.286267 ],
#           [0.298393 ],
#           ...,
#           [0.298393 ],
#           [0.286267 ],
#           [0.27552  ]],
#
#          [[0.269868 ],
#           [0.280307 ],
#           [0.292112 ],
#           ...,
#           [0.292112 ],
#           [0.280307 ],
#           [0.269868 ]],
#
#          [[0.263326 ],
#           [0.273297 ],
#           [0.284581 ],
#           ...,
#           [0.284581 ],
#           [0.273297 ],
#           [0.263326 ]],
#
#          ...,
#
#          [[0.0689872],
#           [0.0660197],
#           [0.0628385],
#           ...,
#           [0.0628385],
#           [0.0660197],
#           [0.0689872]],
#
#          [[0.065984 ],
#           [0.0630611],
#           [0.0599414],
#           ...,
#           [0.0599414],
#           [0.0630611],
#           [0.065984 ]],
#
#          [[0.0631835],
#           [0.0603101],
#           [0.0572553],
#           ...,
#           [0.0572553],
#           [0.0603101],
#           [0.0631835]]],
#
#
#         [[[0.287697 ],
#           [0.299402 ],
#           [0.312602 ],
#           ...,
#           [0.312602 ],
#           [0.299402 ],
#           [0.287697 ]],
#
#          [[0.281537 ],
#           [0.292863 ],
#           [0.305659 ],
#           ...,
#           [0.305659 ],
#           [0.292863 ],
#           [0.281537 ]],
#
#          [[0.274462 ],
#           [0.285247 ],
#           [0.297435 ],
#           ...,
#           [0.297435 ],
#           [0.285247 ],
#           [0.274462 ]],
#
#          ...,
#
#          [[0.070487 ],
#           [0.0674733],
#           [0.0642389],
#           ...,
#           [0.0642389],
#           [0.0674733],
#           [0.070487 ]],
#
#          [[0.0673816],
#           [0.0644132],
#           [0.0612417],
#           ...,
#           [0.0612417],
#           [0.0644132],
#           [0.0673816]],
#
#          [[0.0644876],
#           [0.0615695],
#           [0.0584643],
#           ...,
#           [0.0584643],
#           [0.0615695],
#           [0.0644876]]],
#
#
#         [[[0.299582 ],
#           [0.312164 ],
#           [0.326334 ],
#           ...,
#           [0.326334 ],
#           [0.312164 ],
#           [0.299582 ]],
#
#          [[0.292903 ],
#           [0.305037 ],
#           [0.318719 ],
#           ...,
#           [0.318719 ],
#           [0.305037 ],
#           [0.292903 ]],
#
#          [[0.285293 ],
#           [0.296814 ],
#           [0.309802 ],
#           ...,
#           [0.309802 ],
#           [0.296814 ],
#           [0.285293 ]],
#
#          ...,
#
#          [[0.071972 ],
#           [0.0689119],
#           [0.0656244],
#           ...,
#           [0.0656244],
#           [0.0689119],
#           [0.071972 ]],
#
#          [[0.0687664],
#           [0.0657523],
#           [0.062529 ],
#           ...,
#           [0.062529 ],
#           [0.0657523],
#           [0.0687664]],
#
#          [[0.0657804],
#           [0.0628176],
#           [0.0596621],
#           ...,
#           [0.0596621],
#           [0.0628176],
#           [0.0657804]]]]), array([[[[ 0.024593 , -0.005315 , -0.025021 ],
#           [ 0.024075 , -0.005071 , -0.0257175],
#           [ 0.023433 , -0.004808 , -0.0271175],
#           ...,
#           [ 0.023433 , -0.004808 ,  0.0271175],
#           [ 0.024075 , -0.005071 ,  0.0257175],
#           [ 0.024593 , -0.005315 ,  0.025021 ]],
#
#          [[ 0.024295 , -0.0054925, -0.024777 ],
#           [ 0.023787 , -0.005247 , -0.025464 ],
#           [ 0.023156 , -0.004982 , -0.0268465],
#           ...,
#           [ 0.023156 , -0.004982 ,  0.0268465],
#           [ 0.023787 , -0.005247 ,  0.025464 ],
#           [ 0.024295 , -0.0054925,  0.024777 ]],
#
#          [[ 0.023947 , -0.0058435, -0.02453  ],
#           [ 0.023447 , -0.005596 , -0.025207 ],
#           [ 0.022827 , -0.005327 , -0.026569 ],
#           ...,
#           [ 0.022827 , -0.005327 ,  0.026569 ],
#           [ 0.023447 , -0.005596 ,  0.025207 ],
#           [ 0.023947 , -0.0058435,  0.02453  ]],
#
#          ...,
#
#          [[ 0.008541 , -0.006619 , -0.017426 ],
#           [ 0.008183 , -0.006357 , -0.0176785],
#           [ 0.007794 , -0.006073 , -0.018177 ],
#           ...,
#           [ 0.007794 , -0.006073 ,  0.018177 ],
#           [ 0.008183 , -0.006357 ,  0.0176785],
#           [ 0.008541 , -0.006619 ,  0.017426 ]],
#
#          [[ 0.008139 , -0.0064215, -0.017165 ],
#           [ 0.007791 , -0.0061625, -0.0174075],
#           [ 0.007415 , -0.005883 , -0.0178845],
#           ...,
#           [ 0.007415 , -0.005883 ,  0.0178845],
#           [ 0.007791 , -0.0061625,  0.0174075],
#           [ 0.008139 , -0.0064215,  0.017165 ]],
#
#          [[ 0.007758 , -0.006322 , -0.016908 ],
#           [ 0.00742  , -0.006065 , -0.01714  ],
#           [ 0.007056 , -0.005787 , -0.017597 ],
#           ...,
#           [ 0.007056 , -0.005787 ,  0.017597 ],
#           [ 0.00742  , -0.006065 ,  0.01714  ],
#           [ 0.007758 , -0.006322 ,  0.016908 ]]],
#
#
#         [[[ 0.0255425, -0.005613 , -0.025539 ],
#           [ 0.0250395, -0.005359 , -0.0262975],
#           [ 0.0244065, -0.005085 , -0.0278265],
#           ...,
#           [ 0.0244065, -0.005085 ,  0.0278265],
#           [ 0.0250395, -0.005359 ,  0.0262975],
#           [ 0.0255425, -0.005613 ,  0.025539 ]],
#
#          [[ 0.025231 , -0.0058155, -0.025285 ],
#           [ 0.024739 , -0.005561 , -0.0260335],
#           [ 0.0241185, -0.005285 , -0.027543 ],
#           ...,
#           [ 0.0241185, -0.005285 ,  0.027543 ],
#           [ 0.024739 , -0.005561 ,  0.0260335],
#           [ 0.025231 , -0.0058155,  0.025285 ]],
#
#          [[ 0.024866 , -0.006216 , -0.02503  ],
#           [ 0.0243835, -0.0059605, -0.025767 ],
#           [ 0.0237745, -0.0056805, -0.027253 ],
#           ...,
#           [ 0.0237745, -0.0056805,  0.027253 ],
#           [ 0.0243835, -0.0059605,  0.025767 ],
#           [ 0.024866 , -0.006216 ,  0.02503  ]],
#
#          ...,
#
#          [[ 0.0087055, -0.007031 , -0.017784 ],
#           [ 0.0083435, -0.0067585, -0.018052 ],
#           [ 0.0079505, -0.0064625, -0.0185805],
#           ...,
#           [ 0.0079505, -0.0064625,  0.0185805],
#           [ 0.0083435, -0.0067585,  0.018052 ],
#           [ 0.0087055, -0.007031 ,  0.017784 ]],
#
#          [[ 0.008291 , -0.006813 , -0.017513 ],
#           [ 0.0079385, -0.006544 , -0.0177695],
#           [ 0.0075585, -0.006252 , -0.0182745],
#           ...,
#           [ 0.0075585, -0.006252 ,  0.0182745],
#           [ 0.0079385, -0.006544 ,  0.0177695],
#           [ 0.008291 , -0.006813 ,  0.017513 ]],
#
#          [[ 0.0078975, -0.006703 , -0.017246 ],
#           [ 0.0075555, -0.006436 , -0.017491 ],
#           [ 0.007187 , -0.006146 , -0.0179735],
#           ...,
#           [ 0.007187 , -0.006146 ,  0.0179735],
#           [ 0.0075555, -0.006436 ,  0.017491 ],
#           [ 0.0078975, -0.006703 ,  0.017246 ]]],
#
#
#         [[[ 0.0275315, -0.005938 , -0.026027 ],
#           [ 0.0270665, -0.005672 , -0.0268535],
#           [ 0.0264585, -0.005384 , -0.0285245],
#           ...,
#           [ 0.0264585, -0.005384 ,  0.0285245],
#           [ 0.0270665, -0.005672 ,  0.0268535],
#           [ 0.0275315, -0.005938 ,  0.026027 ]],
#
#          [[ 0.0271925, -0.006169 , -0.025761 ],
#           [ 0.0267405, -0.005903 , -0.0265765],
#           [ 0.026147 , -0.005614 , -0.0282255],
#           ...,
#           [ 0.026147 , -0.005614 ,  0.0282255],
#           [ 0.0267405, -0.005903 ,  0.0265765],
#           [ 0.0271925, -0.006169 ,  0.025761 ]],
#
#          [[ 0.026793 , -0.006625 , -0.025495 ],
#           [ 0.026351 , -0.0063605, -0.0262985],
#           [ 0.02577  , -0.0060695, -0.027923 ],
#           ...,
#           [ 0.02577  , -0.0060695,  0.027923 ],
#           [ 0.026351 , -0.0063605,  0.0262985],
#           [ 0.026793 , -0.006625 ,  0.025495 ]],
#
#          ...,
#
#          [[ 0.009039 , -0.00747  , -0.01815  ],
#           [ 0.0086695, -0.0071885, -0.0184335],
#           [ 0.0082675, -0.006879 , -0.018994 ],
#           ...,
#           [ 0.0082675, -0.006879 ,  0.018994 ],
#           [ 0.0086695, -0.0071885,  0.0184335],
#           [ 0.009039 , -0.00747  ,  0.01815  ]],
#
#          [[ 0.0085975, -0.0072295, -0.01787  ],
#           [ 0.008238 , -0.0069505, -0.01814  ],
#           [ 0.0078485, -0.0066465, -0.0186735],
#           ...,
#           [ 0.0078485, -0.0066465,  0.0186735],
#           [ 0.008238 , -0.0069505,  0.01814  ],
#           [ 0.0085975, -0.0072295,  0.01787  ]],
#
#          [[ 0.008179 , -0.007109 , -0.017592 ],
#           [ 0.0078295, -0.006831 , -0.0178505],
#           [ 0.007453 , -0.00653  , -0.0183595],
#           ...,
#           [ 0.007453 , -0.00653  ,  0.0183595],
#           [ 0.0078295, -0.006831 ,  0.0178505],
#           [ 0.008179 , -0.007109 ,  0.017592 ]]],
#
#
#         ...,
#
#
#         [[[ 0.122875 , -0.05652  ,  0.10747  ],
#           [ 0.13279  , -0.0596   ,  0.114365 ],
#           [ 0.144    , -0.06281  ,  0.129605 ],
#           ...,
#           [ 0.144    , -0.06281  , -0.129605 ],
#           [ 0.13279  , -0.0596   , -0.114365 ],
#           [ 0.122875 , -0.05652  , -0.10747  ]],
#
#          [[ 0.117865 , -0.06097  ,  0.10439  ],
#           [ 0.12709  , -0.06485  ,  0.11122  ],
#           [ 0.13747  , -0.06906  ,  0.126375 ],
#           ...,
#           [ 0.13747  , -0.06906  , -0.126375 ],
#           [ 0.12709  , -0.06485  , -0.11122  ],
#           [ 0.117865 , -0.06097  , -0.10439  ]],
#
#          [[ 0.112585 , -0.069585 ,  0.09971  ],
#           [ 0.121085 , -0.075045 ,  0.106275 ],
#           [ 0.130585 , -0.08123  ,  0.120875 ],
#           ...,
#           [ 0.130585 , -0.08123  , -0.120875 ],
#           [ 0.121085 , -0.075045 , -0.106275 ],
#           [ 0.112585 , -0.069585 , -0.09971  ]],
#
#          ...,
#
#          [[ 0.0150565, -0.0311315, -0.029675 ],
#           [ 0.014596 , -0.0307165, -0.0307435],
#           [ 0.014066 , -0.0301255, -0.0329045],
#           ...,
#           [ 0.014066 , -0.0301255,  0.0329045],
#           [ 0.014596 , -0.0307165,  0.0307435],
#           [ 0.0150565, -0.0311315,  0.029675 ]],
#
#          [[ 0.014028 , -0.0290185, -0.029229 ],
#           [ 0.013573 , -0.028548 , -0.030213 ],
#           [ 0.0130555, -0.027916 , -0.032198 ],
#           ...,
#           [ 0.0130555, -0.027916 ,  0.032198 ],
#           [ 0.013573 , -0.028548 ,  0.030213 ],
#           [ 0.014028 , -0.0290185,  0.029229 ]],
#
#          [[ 0.013086 , -0.028005 , -0.028734 ],
#           [ 0.0126395, -0.02751  , -0.029641 ],
#           [ 0.012136 , -0.026861 , -0.031466 ],
#           ...,
#           [ 0.012136 , -0.026861 ,  0.031466 ],
#           [ 0.0126395, -0.02751  ,  0.029641 ],
#           [ 0.013086 , -0.028005 ,  0.028734 ]]],
#
#
#         [[[ 0.12031  , -0.0616   ,  0.11705  ],
#           [ 0.129485 , -0.06539  ,  0.124525 ],
#           [ 0.139705 , -0.06943  ,  0.14103  ],
#           ...,
#           [ 0.139705 , -0.06943  , -0.14103  ],
#           [ 0.129485 , -0.06539  , -0.124525 ],
#           [ 0.12031  , -0.0616   , -0.11705  ]],
#
#          [[ 0.115175 , -0.066175 ,  0.11326  ],
#           [ 0.12365  , -0.070775 ,  0.12061  ],
#           [ 0.133035 , -0.075835 ,  0.13686  ],
#           ...,
#           [ 0.133035 , -0.075835 , -0.13686  ],
#           [ 0.12365  , -0.070775 , -0.12061  ],
#           [ 0.115175 , -0.066175 , -0.11326  ]],
#
#          [[ 0.109835 , -0.075005 ,  0.10785  ],
#           [ 0.117585 , -0.081205 ,  0.114865 ],
#           [ 0.126105 , -0.088275 ,  0.130395 ],
#           ...,
#           [ 0.126105 , -0.088275 , -0.130395 ],
#           [ 0.117585 , -0.081205 , -0.114865 ],
#           [ 0.109835 , -0.075005 , -0.10785  ]],
#
#          ...,
#
#          [[ 0.014924 , -0.0322   , -0.030137 ],
#           [ 0.014461 , -0.03178  , -0.0312405],
#           [ 0.0139295, -0.031177 , -0.033471 ],
#           ...,
#           [ 0.0139295, -0.031177 ,  0.033471 ],
#           [ 0.014461 , -0.03178  ,  0.0312405],
#           [ 0.014924 , -0.0322   ,  0.030137 ]],
#
#          [[ 0.013912 , -0.029997 , -0.029684 ],
#           [ 0.013456 , -0.029519 , -0.0306995],
#           [ 0.012938 , -0.028873 , -0.0327475],
#           ...,
#           [ 0.012938 , -0.028873 ,  0.0327475],
#           [ 0.013456 , -0.029519 ,  0.0306995],
#           [ 0.013912 , -0.029997 ,  0.029684 ]],
#
#          [[ 0.0129845, -0.02894  , -0.029181 ],
#           [ 0.0125375, -0.028437 , -0.0301165],
#           [ 0.012034 , -0.027774 , -0.0319985],
#           ...,
#           [ 0.012034 , -0.027774 ,  0.0319985],
#           [ 0.0125375, -0.028437 ,  0.0301165],
#           [ 0.0129845, -0.02894  ,  0.029181 ]]],
#
#
#         [[[ 0.11885  , -0.06679  ,  0.12582  ],
#           [ 0.12762  , -0.07127  ,  0.13376  ],
#           [ 0.13732  , -0.07615  ,  0.15124  ],
#           ...,
#           [ 0.13732  , -0.07615  , -0.15124  ],
#           [ 0.12762  , -0.07127  , -0.13376  ],
#           [ 0.11885  , -0.06679  , -0.12582  ]],
#
#          [[ 0.11366  , -0.071445 ,  0.12134  ],
#           [ 0.12174  , -0.07675  ,  0.12908  ],
#           [ 0.1306   , -0.08266  ,  0.14615  ],
#           ...,
#           [ 0.1306   , -0.08266  , -0.14615  ],
#           [ 0.12174  , -0.07675  , -0.12908  ],
#           [ 0.11366  , -0.071445 , -0.12134  ]],
#
#          [[ 0.10831  , -0.080425 ,  0.11521  ],
#           [ 0.11567  , -0.087345 ,  0.122545 ],
#           [ 0.12367  , -0.095265 ,  0.138745 ],
#           ...,
#           [ 0.12367  , -0.095265 , -0.138745 ],
#           [ 0.11567  , -0.087345 , -0.122545 ],
#           [ 0.10831  , -0.080425 , -0.11521  ]],
#
#          ...,
#
#          [[ 0.01485  , -0.033248 , -0.030601 ],
#           [ 0.014386 , -0.0328225, -0.031738 ],
#           [ 0.013855 , -0.0322065, -0.034038 ],
#           ...,
#           [ 0.013855 , -0.0322065,  0.034038 ],
#           [ 0.014386 , -0.0328225,  0.031738 ],
#           [ 0.01485  , -0.033248 ,  0.030601 ]],
#
#          [[ 0.013848 , -0.030958 , -0.030141 ],
#           [ 0.013391 , -0.0304715, -0.031187 ],
#           [ 0.012873 , -0.0298115, -0.0332975],
#           ...,
#           [ 0.012873 , -0.0298115,  0.0332975],
#           [ 0.013391 , -0.0304715,  0.031187 ],
#           [ 0.013848 , -0.030958 ,  0.030141 ]],
#
#          [[ 0.012928 , -0.02986  , -0.029628 ],
#           [ 0.012481 , -0.029347 , -0.0305915],
#           [ 0.011978 , -0.028669 , -0.03253  ],
#           ...,
#           [ 0.011978 , -0.028669 ,  0.03253  ],
#           [ 0.012481 , -0.029347 ,  0.0305915],
#           [ 0.012928 , -0.02986  ,  0.029628 ]]]])]

# %%
from scipy.constants import atomic_mass
x0 = s.minimum((0, 0, 1.))
for _ in s.analyze_static(x0, m=25*atomic_mass, u=50.,      # u is V rf peak voltage, but it causes error.
                          l=40e-6, o=100e6*2*np.pi):
    print(_)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-d827221c81a4> in <module>()
#       1 from scipy.constants import atomic_mass
# ----> 2 x0 = s.minimum((0, 0, 1.))
#       3 for _ in s.analyze_static(x0, m=25*atomic_mass, u=50.,      # u is V rf peak voltage, but it causes error.
#       4                           l=40e-6, o=100e6*2*np.pi):
#       5     print(_)
#
# ~/bem_git/electrode/electrode/system.py in minimum(self, x0, axis, coord, method, **kwargs)
#     429         x0 = np.array(x0)[axis]
#     430         res = optimize.minimize(fun=f, x0=x0, jac=g, hess=h,
# --> 431             method=method, **kwargs)
#     432         if not res.success:
#     433             raise ValueError("failed, %i, %s, %s" % (res.success,
#
# ~/anaconda3/envs/elec36/lib/python3.6/site-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     598     elif meth == 'newton-cg':
#     599         return _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
# --> 600                                   **options)
#     601     elif meth == 'l-bfgs-b':
#     602         return _minimize_lbfgsb(fun, x0, args, jac, bounds,
#
# ~/anaconda3/envs/elec36/lib/python3.6/site-packages/scipy/optimize/optimize.py in _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback, xtol, eps, maxiter, disp, return_all, **unknown_options)
#    1544         # Compute a search direction pk by applying the CG method to
#    1545         #  del2 f(xk) p = - grad f(xk) starting from 0.
# -> 1546         b = -fprime(xk)
#    1547         maggrad = numpy.add.reduce(numpy.abs(b))
#    1548         eta = numpy.min([0.5, numpy.sqrt(maggrad)])
#
# ~/anaconda3/envs/elec36/lib/python3.6/site-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     291     def function_wrapper(*wrapper_args):
#     292         ncalls[0] += 1
# --> 293         return function(*(wrapper_args + args))
#     294
#     295     return ncalls, function_wrapper
#
# ~/bem_git/electrode/electrode/system.py in g(xi)
#     419         def g(xi):
#     420             x[axis] = xi
# --> 421             return rotate_tensor(self.potential(np.dot(coord, x), 1),
#     422                     coord)[0, axis]
#     423         def h(xi):
#
# ~/bem_git/electrode/electrode/system.py in potential(self, x, derivative)
#     340         dc = self.electrical_potential(x, "dc", derivative,
#     341                 expand=True)
# --> 342         rf = self.pseudo_potential(x, derivative)
#     343         return dc + rf
#     344
#
# ~/bem_git/electrode/electrode/system.py in pseudo_potential(self, x, derivative)
#     291         """
#     292         p = [self.electrical_potential(x, "rf", i, expand=True)
# --> 293                 for i in range(1, derivative+2)]
#     294         if derivative == 0:
#     295             return np.einsum("ij,ij->i", p[0], p[0])
#
# ~/bem_git/electrode/electrode/system.py in <listcomp>(.0)
#     291         """
#     292         p = [self.electrical_potential(x, "rf", i, expand=True)
# --> 293                 for i in range(1, derivative+2)]
#     294         if derivative == 0:
#     295             return np.einsum("ij,ij->i", p[0], p[0])
#
# ~/bem_git/electrode/electrode/system.py in electrical_potential(self, x, typ, derivative, expand)
#     214             vi = getattr(ei, typ, None)
#     215             if vi:
# --> 216                 ei.potential(x, derivative, potential=vi, out=pot)
#     217         if expand:
#     218             pot = expand_tensor(pot)
#
# ~/bem_git/electrode/electrode/electrode.py in potential(self, x, derivative, potential, out)
#     533         if out is None:
#     534             out = np.zeros((x.shape[0], 2*derivative+1), np.double)
# --> 535         dat = self.data[derivative]
#     536         for i in range(2*derivative+1):
#     537             out[:, i] += potential*map_coordinates(dat[..., i], x.T,
#
# IndexError: list index out of range
